# %% [markdown]
# # load Data

# %%
import pandas as pd


df = pd.read_csv(r"C:\Users\Computec\Desktop\depiiii\heart_data1_cleaned1.csv")  
df.head()
# Out:
#    id  age age_distribution  gender cholesterol          gluc     smoke  \
# 0   0   25            25-29  female    elevated  pre diabetic  no-smoke
# 1   1   25            25-29  female      normal        normal  no-smoke
# 2   2   25            25-29  female    elevated        normal  no-smoke
# 3   3   25            25-29  female      normal        normal  no-smoke
# 4   4   25            25-29  female      normal        normal  no-smoke
#
#        alco      active  height  weight    BMI      BMI_Class  ap_hi  ap_lo  \
# 0  non-alco      active     149      54  24.32  Normal weight    177     78
# 1  non-alco      active     146      55  25.80    Over weight    149     95
# 2  non-alco  non-active     145      75  35.67          Obese    141     98
# 3      alco  non-active     158      79  31.65          Obese    135     95
# 4  non-alco      active     178      62  19.57  Normal weight    155     98
#
#                BP_Class Blood pressure      CVD
# 0  Hypertension Stage 2         normal  non-cvd
# 1  Hypertension Stage 2         normal  non-cvd
# 2  Hypertension Stage 2         normal  non-cvd
# 3  Hypertension Stage 1         normal  non-cvd
# 4  Hypertension Stage 2        type 1   non-cvd

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                300000 non-null  int64
#  1   age               300000 non-null  int64
#  2   age_distribution  300000 non-null  object
#  3   gender            300000 non-null  object
#  4   cholesterol       300000 non-null  object
#  5   gluc              300000 non-null  object
#  6   smoke             300000 non-null  object
#  7   alco              300000 non-null  object
#  8   active            300000 non-null  object
#  9   height            300000 non-null  int64
#  10  weight            300000 non-null  int64
#  11  BMI               300000 non-null  float64
#  12  BMI_Class         300000 non-null  object
#  13  ap_hi             300000 non-null  int64
#  14  ap_lo             300000 non-null  int64
#  15  BP_Class          300000 non-null  object
#  16  Blood pressure    300000 non-null  object
#  17  CVD               300000 non-null  object
# dtypes: float64(1), int64(6), object(11)
# memory usage: 41.2+ MB

# %%
df.describe()
# Out:
#                   id            age         height         weight  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   149999.500000      52.720307     167.849013      96.466167
# std     86602.684716      12.816043      12.119234      37.846784
# min         0.000000      25.000000     145.000000      45.000000
# 25%     74999.750000      40.000000     158.000000      67.000000
# 50%    149999.500000      56.000000     168.000000      87.000000
# 75%    224999.250000      61.000000     177.000000     118.000000
# max    299999.000000      84.000000     194.000000     199.000000
#
#                  BMI         ap_hi          ap_lo
# count  300000.000000  300000.00000  300000.000000
# mean       34.714817     134.53833      84.489777
# std        14.448891      25.94098      14.425929
# min        13.290000      90.00000      60.000000
# 25%        23.670000     112.00000      72.000000
# 50%        30.850000     135.00000      84.000000
# 75%        42.940000     157.00000      97.000000
# max        88.440000     179.00000     109.000000

# %%
print(df.isna().sum())
# Out:
# id                  0
# age                 0
# age_distribution    0
# gender              0
# cholesterol         0
# gluc                0
# smoke               0
# alco                0
# active              0
# height              0
# weight              0
# BMI                 0
# BMI_Class           0
# ap_hi               0
# ap_lo               0
# BP_Class            0
# Blood pressure      0
# CVD                 0
# dtype: int64

# %%
df = df.drop(columns=['id'])

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(15, 10), bins=30)
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
df['gender'].value_counts(dropna=False)
# Out:
# gender
# male      180000
# female    120000
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='CVD', data=df)
plt.title("Cardiovascular Disease Distribution")
plt.show()


sns.countplot(x='gender', data=df)    
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# # Outlier Detection

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = ["age", "height", "weight", "BMI", "ap_hi", "ap_lo"]

plt.figure(figsize=(12, 8))
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()
